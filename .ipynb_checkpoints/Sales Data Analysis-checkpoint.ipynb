# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Train.csv')
df.tail(4)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8519           FDS36         8.38          Regular         0.046982
# 8520           NCJ29        10.60          Low Fat         0.035186
# 8521           FDN46         7.21          Regular         0.145221
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700

# %% [markdown]
# ## Data cleaning:-

# %%
df.shape
# Out:
# (8523, 12)

# %%
print('Columns Names:\n',df.columns)
# Out:
# Columns Names:
#  Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
print('Unique Item Types:',len(df['Item_Type'].unique()))
# Out:
# Unique Item Types: 16

# %%
print('Item Type Names:-\n')
for n in df['Item_Type'].unique():
    print(n)
# Out:
# Item Type Names:-
#
# Dairy
# Soft Drinks
# Meat
# Fruits and Vegetables
# Household
# Baking Goods
# Snack Foods
# Frozen Foods
# Breakfast
# Health and Hygiene
# Hard Drinks
# Canned
# Breads
# Starchy Foods
# Others
# Seafood

# %%
plt.rcParams['font.size'] =14
plt.figure(figsize=(10,4))
sns.heatmap(df.isnull(),cmap='viridis',cbar=False)
plt.title('Null values for The hole Data Sets')
plt.show()

# %%
supermarket1 = df[df['Outlet_Type'] =='Supermarket Type1']
supermarket2 = df[df['Outlet_Type'] =='Supermarket Type2']
supermarket3 = df[df['Outlet_Type'] =='Supermarket Type3']
grocery = df[df['Outlet_Type'] =='Grocery Store']

# %%
plt.rcParams['font.size'] =14
plt.figure(figsize=(10,4))
sns.heatmap(supermarket1.isnull(),cmap='viridis',cbar=False)
plt.title('Null values for The Super Market Type-1')
plt.show()

# %%
plt.rcParams['font.size'] =14
plt.figure(figsize=(10,4))
sns.heatmap(supermarket2.isnull(),cmap='viridis',cbar=False)
plt.title('Null values for The Super Market Type-2')
plt.show()

# %%
plt.rcParams['font.size'] =14
plt.figure(figsize=(10,4))
sns.heatmap(supermarket3.isnull(),cmap='viridis',cbar=False)
plt.title('Null values for The Super Market Type-3')
plt.show()

# %%
plt.rcParams['font.size'] =14
plt.figure(figsize=(10,4))
sns.heatmap(grocery.isnull(),cmap='viridis',cbar=False)
plt.title('Null values for The Grocery Shop')
plt.show()

# %%
print('Type of Outlet Size:',df.Outlet_Size.unique())
# Out:
# Type of Outlet Size: ['Medium' nan 'High' 'Small']

# %%
print('Outlet Locations:',df.Outlet_Location_Type.unique())
# Out:
# Outlet Locations: ['Tier 1' 'Tier 3' 'Tier 2']

# %%
supermarket1[supermarket1['Outlet_Location_Type'] == 'Tier 2'].isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1855
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
supermarket1[supermarket1['Outlet_Location_Type'] == 'Tier 2'].Outlet_Size.unique()
# Out:
# array([nan, 'Small'], dtype=object)

# %% [markdown]
# **here we can see that all the outlet sizes are 'Small' & 'nan' in suppermarket type-1 of Tier-2 city, so we can replace 'nan' values to 'small'...**

# %%
grocery['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 3', 'Tier 1'], dtype=object)

# %%
grocery[grocery['Outlet_Location_Type'] == 'Tier 1'].isnull().sum()
# Out:
# Item_Identifier                0
# Item_Weight                  528
# Item_Fat_Content               0
# Item_Visibility                0
# Item_Type                      0
# Item_MRP                       0
# Outlet_Identifier              0
# Outlet_Establishment_Year      0
# Outlet_Size                    0
# Outlet_Location_Type           0
# Outlet_Type                    0
# Item_Outlet_Sales              0
# dtype: int64

# %%
grocery[grocery['Outlet_Location_Type'] == 'Tier 3'].isnull().sum()
# Out:
# Item_Identifier                0
# Item_Weight                    0
# Item_Fat_Content               0
# Item_Visibility                0
# Item_Type                      0
# Item_MRP                       0
# Outlet_Identifier              0
# Outlet_Establishment_Year      0
# Outlet_Size                  555
# Outlet_Location_Type           0
# Outlet_Type                    0
# Item_Outlet_Sales              0
# dtype: int64

# %%
grocery[grocery['Outlet_Location_Type'] == 'Tier 3'].Outlet_Size.unique()
# Out:
# array([nan], dtype=object)

# %% [markdown]
# **here we can see that all the outlet sizes are  'nan' in grocery of Tier-3 city
# so we can replace 'nan' values to 'small'...**

# %%
df.Outlet_Size.isnull().sum() == 555 + 1855
# Out:
# True

# %%
df.Outlet_Size.fillna("Small",inplace= True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.Item_Weight.isna().sum()
# Out:
# 1463

# %%
supermarket3.shape
# Out:
# (935, 12)

# %%
supermarket3.Item_Weight.isna().sum()
# Out:
# 935

# %%
grocery.Item_Weight.shape
# Out:
# (1083,)

# %%
grocery.Item_Weight.isna().sum()
# Out:
# 528

# %% [markdown]
# **So we found that In Super Market type-3 Item weights are not given to any item how ever in grocery shop almost 50% items have not given item weights....**

# %%
df.Item_Weight.mean()
# Out:
# 12.857645184136183

# %%
grocery.Item_Weight.mean()
# Out:
# 12.91315315315319

# %%
df.Item_Weight.fillna(grocery.Item_Weight.mean(), inplace = True)

# %%
plt.rcParams['font.size'] =14
plt.figure(figsize=(10,4))
sns.heatmap(df.isnull(),cmap='viridis',cbar=False)
plt.title('Dataset is cleaned')
plt.show()

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
df['Outlet_Size'].unique()
# Out:
# array(['Medium', 'Small', 'High'], dtype=object)

# %%
df.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %% [markdown]
# #### Mapping the duplicate names of Item_Fat_Content

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].map({'Low Fat':'low_fat','low fat':'low_fat','LF':'low_fat','reg':'regular','Regular':'regular'})

# %%
df.Item_Fat_Content.unique()
# Out:
# array(['low_fat', 'regular'], dtype=object)

# %%
df['Outlet_Size'].unique()
# Out:
# array(['Medium', 'Small', 'High'], dtype=object)

# %% [markdown]
# # Story-line of Data

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.867173         0.066132   140.992782                1997.831867
# std       4.226176         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.913153         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
print('Number of items per Item types:-\n')
print(df['Item_Type'].value_counts())
# Out:
# Number of items per Item types:-
#
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
print('Total Sales of Food Type in all Shops:-')
plt.rcParams['font.size'] =15
plt.figure(figsize=(20,8))
sns.barplot(x=df['Item_Type'],y=df['Item_Outlet_Sales'])
plt.show()
# Out:
# Total Sales of Food Type in all Shops:-

# %%
print('Total Food Types:-')
plt.rcParams['font.size'] =14
plt.figure(figsize=(20,8))
sns.barplot(x=df['Item_Type'].unique(),y=df['Item_Type'].value_counts(),saturation=0.9)
plt.title('I T E M S')
plt.ylabel('NUMBERS ->')
plt.xlabel('ITEM - TYPES ->')
plt.show()
# Out:
# Total Food Types:-

# %%
plt.rcParams['font.size'] =14
f,(ax1,ax2) = plt.subplots(1,2,figsize=(20,6))
sns.barplot(x=df['Outlet_Type'].unique(),y=df['Outlet_Type'].value_counts(), ax=ax1)
sns.barplot(x=df['Outlet_Location_Type'],y=df['Item_Outlet_Sales'], ax=ax2)
ax1.set_title('O U T L E T - T Y P E - C O U N T')
ax2.set_title('O U T L E T - L O C A T I O N - S A L E S')
plt.show()

# %%
print('Total Number of Super Market-1: ',len(supermarket1))
plt.rcParams['font.size'] =14
plt.figure(figsize=(20,8))
sns.barplot(x=supermarket1['Item_Type'].unique(),y=supermarket1['Item_Type'].value_counts(),saturation=0.9)
plt.title('I T E M S  IN SUPERMARKET TYPE-1')
plt.ylabel('NUMBERS ->')
plt.xlabel('ITEM - TYPES ->')
plt.show()
# Out:
# Total Number of Super Market-1:  5577

# %%
plt.rcParams['font.size'] =15
plt.figure(figsize=(20,8))
sns.barplot(x=supermarket1['Item_Type'],y=supermarket1['Item_Outlet_Sales'])
plt.title('Total Sales of Food Type in Super Market-1:-')
plt.show()

# %%
print('Total Number of Super Market Type-2: ',len(supermarket2))
plt.figure(figsize=(20,8))
plt.rcParams['font.size'] =14
sns.barplot(x=supermarket2['Item_Type'].unique(),y=supermarket2['Item_Type'].value_counts(),saturation=0.9)
plt.title('I T E M S  IN  SUPERMARKET  TYPE-2')
plt.ylabel('NUMBERS ->')
plt.xlabel('ITEM - TYPES ->')
plt.show()
# Out:
# Total Number of Super Market Type-2:  928

# %%
plt.rcParams['font.size'] =15
plt.figure(figsize=(20,8))
sns.barplot(x=supermarket2['Item_Type'],y=supermarket2['Item_Outlet_Sales'])
plt.title('Total Sales of Food Type in Super Market-2:-')
plt.show()

# %%
print('Total Number of Super Market-3: ',len(supermarket3))
plt.figure(figsize=(20,8))
plt.rcParams['font.size'] =14
sns.barplot(x=supermarket3['Item_Type'].unique(),y=supermarket3['Item_Type'].value_counts(),saturation=0.9)
plt.title('I T E M S  IN  SUPERMARKET  TYPE-3')
plt.ylabel('NUMBERS ->')
plt.xlabel('ITEM - TYPES ->')
plt.show()
# Out:
# Total Number of Super Market-3:  935

# %%
plt.rcParams['font.size'] =15
plt.figure(figsize=(20,8))
sns.barplot(x=supermarket3['Item_Type'],y=supermarket3['Item_Outlet_Sales'])
plt.title('Total Sales of Food Type in Super Market-3:-')
plt.show()

# %%
print('Total Number of Grocery Shop: ',len(grocery))
plt.figure(figsize=(20,8))
plt.rcParams['font.size'] =14
sns.barplot(x=grocery['Item_Type'].unique(),y=grocery['Item_Type'].value_counts(),saturation=0.9)
plt.title('I T E M S  IN  GROCERY STORE')
plt.ylabel('NUMBERS ->')
plt.xlabel('ITEM - TYPES ->')
plt.show()
# Out:
# Total Number of Grocery Shop:  1083

# %%
plt.rcParams['font.size'] =15
plt.figure(figsize=(20,8))
sns.barplot(x=grocery['Item_Type'],y=grocery['Item_Outlet_Sales'])
plt.title('Total Sales of Food Type in Grocery Shops:-')
plt.show()

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          low_fat         0.056783
# 8519           FDS36        8.380          regular         0.046982
# 8520           NCJ29       10.600          low_fat         0.035186
# 8521           FDN46        7.210          regular         0.145221
# 8522           DRG01       14.800          low_fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002       Small               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700

# %%
df.Outlet_Size.unique()
# Out:
# array(['Medium', 'Small', 'High'], dtype=object)

# %%
print('Total Sales According to Different Outlet Size:---')
plt.rcParams['font.size'] =14
f,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(20,6))
sns.barplot(x=supermarket1['Outlet_Size'],y=supermarket1['Item_Outlet_Sales'], ax= ax1)
sns.barplot(x=supermarket2['Outlet_Size'],y=supermarket2['Item_Outlet_Sales'], ax= ax2)
sns.barplot(x=supermarket3['Outlet_Size'],y=supermarket3['Item_Outlet_Sales'], ax= ax3)
sns.barplot(x=grocery['Outlet_Size'],y=grocery['Item_Outlet_Sales'], ax= ax4)

ax1.set_title('SUPER MARKET-1')
ax2.set_title('SUPER MARKET-2')
ax3.set_title('SUPER MARKET-3')
ax4.set_title('GROCERY SHOP')
plt.show()
# Out:
# Total Sales According to Different Outlet Size:---

# %%
print('Total Sales According to Different Location :---')
plt.rcParams['font.size'] =14
f,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(20,6))
sns.barplot(x=supermarket1['Outlet_Location_Type'],y=supermarket1['Item_Outlet_Sales'], ax= ax1)
sns.barplot(x=supermarket2['Outlet_Location_Type'],y=supermarket2['Item_Outlet_Sales'], ax= ax2)
sns.barplot(x=supermarket3['Outlet_Location_Type'],y=supermarket3['Item_Outlet_Sales'], ax= ax3)
sns.barplot(x=grocery['Outlet_Location_Type'],y=grocery['Item_Outlet_Sales'], ax= ax4)

ax1.set_title('SUPER MARKET-1')
ax2.set_title('SUPER MARKET-2')
ax3.set_title('SUPER MARKET-3')
ax4.set_title('GROCERY SHOP')
plt.show()
# Out:
# Total Sales According to Different Location :---

# %%
loc1 = df[df['Outlet_Location_Type']== 'Tier 1']
loc2 = df[df['Outlet_Location_Type']== 'Tier 2']
loc3 = df[df['Outlet_Location_Type']== 'Tier 3']

# %%
print('TOTAL SALES ACCORDING TO FAT CONTENT IN DIFFERENT LOCATIONS:---')
plt.rcParams['font.size'] =14
f,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,6))
sns.barplot(x=loc1['Item_Fat_Content'],y=loc1['Item_Outlet_Sales'], ax= ax1)
sns.barplot(x=loc2['Item_Fat_Content'],y=loc2['Item_Outlet_Sales'], ax= ax2)
sns.barplot(x=loc3['Item_Fat_Content'],y=loc3['Item_Outlet_Sales'], ax= ax3)


ax1.set_title('TIER 1')
ax2.set_title('TIER 2')
ax3.set_title('TIER 3')

plt.show()
# Out:
# TOTAL SALES ACCORDING TO FAT CONTENT IN DIFFERENT LOCATIONS:---

# %% [markdown]
# # EDA

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# low_fat    5517
# regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
supermarket1['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3347
# Regular    1889
# LF          192
# reg          79
# low fat      70
# Name: Item_Fat_Content, dtype: int64

# %%
del df['Item_Identifier'] , df['Outlet_Identifier']

# %% [markdown]
# **Deleted two columns 'Item_Identifier' and 'Outlet_Identifier'**

# %%
df.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Establishment_Year', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          low_fat         0.016047                  Dairy
# 1         5.92          regular         0.019278            Soft Drinks
# 2        17.50          low_fat         0.016760                   Meat
# 3        19.20          regular         0.000000  Fruits and Vegetables
# 4         8.93          low_fat         0.000000              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092                       1999      Medium               Tier 1
# 1   48.2692                       2009      Medium               Tier 3
# 2  141.6180                       1999      Medium               Tier 1
# 3  182.0950                       1998       Small               Tier 3
# 4   53.8614                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# **Now will do the label encoding for categorical values**

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics

# %%
df['Item_Fat_Content'].replace({'low_fat':1,'regular':2},inplace = True)
df['Outlet_Size'].replace({'Small':1,'Medium':2,'High':3},inplace = True)
df['Outlet_Location_Type'].replace({'Tier 1':3,'Tier 2':2,'Tier 3':1},inplace = True)
df['Outlet_Type'].replace({'Supermarket Type1':4,'Supermarket Type2':3,'Supermarket Type3':2,'Grocery Store':1},inplace = True)

# %%
encoder = LabelEncoder()

# %%
df['Item_Type'] = encoder.fit_transform(df['Item_Type'])

# %%
df.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 1         0.016047          4  249.8092
# 1         5.92                 2         0.019278         14   48.2692
# 2        17.50                 1         0.016760         10  141.6180
# 3        19.20                 2         0.000000          6  182.0950
# 4         8.93                 1         0.000000          9   53.8614
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            2                     3            4
# 1                       2009            2                     1            3
# 2                       1999            2                     3            4
# 3                       1998            1                     1            1
# 4                       1987            3                     1            4
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           732.3800
# 4           994.7052

# %%
df.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Establishment_Year', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
plt.rcParams['font.size'] =14
f,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,7))
ax1.scatter(df['Item_Weight'],df['Item_Outlet_Sales'],c=df['Item_Outlet_Sales'],marker='.',cmap='viridis')
ax2.scatter(df['Item_Visibility'],df['Item_Outlet_Sales'],c=df['Item_Outlet_Sales'],marker='.',cmap='viridis')
ax3.scatter(df['Item_MRP'],df['Item_Outlet_Sales'],c=df['Item_Outlet_Sales'],marker='.',cmap='viridis')


ax1.set_xlabel('Item_Weight')
ax1.set_ylabel('Item_Outlet_Sales')
ax2.set_xlabel('Item_Visibility')
ax2.set_ylabel('Item_Outlet_Sales')
ax3.set_xlabel('Item_MRP')
ax3.set_ylabel('Item_Outlet_Sales')
sns.despine()
plt.show()

# %%
col1 = ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales']
col2 = ['Item_Type', 'Outlet_Establishment_Year', 'Outlet_Location_Type', 'Outlet_Type']

# %%
print('Box Plots:')
for c1, c2 in zip(col1, col2):
    plt.rcParams['font.size'] =14
    f,(ax1,ax2)=plt.subplots(1,2,figsize=(20,4))
    sns.boxplot(df[c1],color='m', ax=ax1)
    sns.boxplot(df[c2],color='r', ax = ax2)
    plt.show()
# Out:
# Box Plots:

# %%
print('Standard Normal Distributions :')
for c1, c2 in zip(col1, col2):
    plt.rcParams['font.size'] =14
    f,(ax1,ax2)=plt.subplots(1,2,figsize=(20,4))
    sns.distplot(df[c1],color='m', ax=ax1)
    sns.distplot(df[c2],color='r', ax = ax2)
    plt.show()
# Out:
# Standard Normal Distributions :

# %% [markdown]
# ## Different Feature Selection methods

# %% [markdown]
# ###### 1.Feature Corelation

# %%
corr = df.corr()
out = corr[['Item_Outlet_Sales']]
out = out.sort_values(by='Item_Outlet_Sales',ascending=True)

# %%
plt.rcParams['font.size'] =14
print("\n   Feature Importance:")
plt.figure(figsize=(18,2))
sns.heatmap(out.T,annot=True,fmt='.3g',linewidths=0.5,cbar=False,cmap='viridis')
plt.show()
# Out:
#    Feature Importance:

# %% [markdown]
# **From the above heatmap we can say that Item Weight , Item Type & Item Fat Content has very less corelation with Outlet Sales. So I can remove these three items.**
#
# **Also we can see that there are 4 columns 'Outlet_Establishment_Year', 'Item_Visibility', 'Outlet_Location_Type' ,'Outlet_Establishment_Year' are negatively related with the 'Item_Outlet_Sales'**

# %% [markdown]
# ##### 2.Feature Selection LASSO Method

# %%
df.Outlet_Establishment_Year.min(), df.Outlet_Establishment_Year.max()
# Out:
# (1985, 2009)

# %%
df['Years'] = 2010 - df['Outlet_Establishment_Year']

# %%
df.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 1         0.016047          4  249.8092
# 1         5.92                 2         0.019278         14   48.2692
# 2        17.50                 1         0.016760         10  141.6180
# 3        19.20                 2         0.000000          6  182.0950
# 4         8.93                 1         0.000000          9   53.8614
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            2                     3            4
# 1                       2009            2                     1            3
# 2                       1999            2                     3            4
# 3                       1998            1                     1            1
# 4                       1987            3                     1            4
#
#    Item_Outlet_Sales  Years
# 0          3735.1380     11
# 1           443.4228      1
# 2          2097.2700     11
# 3           732.3800     12
# 4           994.7052     23

# %%
del df['Outlet_Establishment_Year']

# %%
df.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Item_Outlet_Sales', 'Years'],
#       dtype='object')

# %% [markdown]
# **making log mathod towords normal distribution**

# %%
df['Item_Visibility'] = np.log(1+df['Item_Visibility'])
df['Item_MRP'] = np.log(1+df['Item_MRP'])
df['Item_Weight'] = np.log(1+df['Item_Weight'])

# %%
plt.rcParams['font.size'] =14
f,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,6))
sns.distplot(df['Item_Visibility'],color='m', ax=ax1)
sns.distplot(df['Item_MRP'],color='m', ax=ax2)
sns.distplot(df['Item_Weight'],color='m', ax=ax3)

sns.despine()
plt.show()

# %%
from sklearn.linear_model import Lasso
import pickle
import xgboost 
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
y = df['Item_Outlet_Sales'].copy()

# %%
x = df.drop(['Item_Outlet_Sales'],axis=1).copy()

# %%
lasso = Lasso(alpha=0.1, max_iter=2000)
lasso.fit(x,y)
# Out:
# Lasso(alpha=0.1, max_iter=2000)

# %%
coeff_values = pd.DataFrame({'coeff':lasso.coef_},index=x.columns).sort_values(by='coeff')
c = (abs(coeff_values.coeff) > 0)
col_imp = list(x.columns[c])
print("Important columns according to Lasso regression :-\n")
for i in col_imp:
    print(i)
# Out:
# Important columns according to Lasso regression :-
#
# Item_Weight
# Item_Fat_Content
# Item_Visibility
# Item_Type
# Item_MRP
# Outlet_Size
# Outlet_Location_Type
# Outlet_Type
# Years

# %% [markdown]
# **so according to Lasso method we can find there is no duplicate features**

# %% [markdown]
# **3. Removal of Constant and Quasi constant from 9 features if any**

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
def Const_remove(x):
    const = VarianceThreshold(threshold=0.01)
    const.fit(x)
    c = const.get_support()
    feature_important = x.columns[c]
    print("Reduced :",(len(x.columns)-len(feature_important)), 'columns')
    return x[feature_important]

# %%
important_features = Const_remove(x)
print('Important Features:\n',important_features.columns)
# Out:
# Reduced : 1 columns
# Important Features:
#  Index(['Item_Weight', 'Item_Fat_Content', 'Item_Type', 'Item_MRP',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'Years'],
#       dtype='object')

# %%
x.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Years'],
#       dtype='object')

# %% [markdown]
# **so in this method we can find 'Item_Visibility' is almost constant feature**

# %% [markdown]
# #### 4. Duplicate Removal if any

# %%
def dupRemove(X):
    xt = X.T
    d = xt.duplicated()
    d1 = []
    for i in d:
        if i != True:
            d1.append(True)
    cln = X.columns[d1]
    print('Number of duplicade columns removed:',d.sum())
    return list(cln)

# %%
duplicate = dupRemove(x)
# Out:
# Number of duplicade columns removed: 0

# %% [markdown]
# **so according to this method we can find there is no duplicate features**

# %%
x.drop(['Item_Weight'], axis=1,inplace= True)

# %%
x.columns
# Out:
# Index(['Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'Years'],
#       dtype='object')

# %%
xg_model = XGBRegressor(random_state=42, n_jobs=-1, objective='reg:squarederror')

# %%
x_train, x_val, y_train, y_val = train_test_split(x,y, test_size=0.1, random_state=42)

# %%
len(x_train), len(y_val)
# Out:
# (7670, 853)

# %% [markdown]
# # model building and evaluation

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
def evaluate(model):
    model.fit(x_train, y_train)
    train_pred = model.predict(x_train)
    train_rmse = mean_squared_error(y_train, train_pred, squared=False)
    val_pred = model.predict(x_val)
    val_rmse = mean_squared_error(y_val, val_pred, squared=False)
    r2_train= r2_score(y_train, train_pred)
    r2_val = r2_score(y_val, val_pred)
    print('train RMSE                 :', train_rmse)
    print('validatin RMSE             :', val_rmse)
    print('R2 Score on Validation data:',r2_val)
    print('R2 Score on training data  :',r2_train)
    return model

# %%
evaluate(xg_model)
# Out:
# train RMSE                 : 699.4748401962902
# validatin RMSE             : 1094.8776303679986
# R2 Score on Validation data: 0.5712376446624681
# R2 Score on training data  : 0.8326927071510221
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100,
#              n_jobs=-1, num_parallel_tree=1, predictor='auto', random_state=42,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
grid = {'n_estimators':[80,100,120,130,140],
               'max_depth': [2,3,4,5],
       'learning_rate':[0.1,0.2]}

# %%
xgbr = RandomizedSearchCV(estimator = xg_model, param_distributions = grid,
                          scoring='neg_mean_squared_error', n_iter = 20, cv = 5, verbose = 1, n_jobs = 1)

# %%
xgbr.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                           callbacks=None, colsample_bylevel=1,
#                                           colsample_bynode=1,
#                                           colsample_bytree=1,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, gamma=0, gpu_id=-1,
#                                           grow_policy='depthwise',
#                                           importance_type=None,
#                                           interaction_constraints='',
#                                           learning_rate=0.300000012,
#                                           max_bin=256, m...
#                                           max_delta_step=0, max_depth=6,
#                                           max_leaves=0, min_child_weight=1,
#                                           missing=nan,
#                                           monotone_constraints='()',
#                                           n_estimators=100, n_jobs=-1,
#                                           num_parallel_tree=1, predictor='auto',
#                                           random_state=42, reg_alpha=0,
#                                           reg_lambda=1, ...),
#                    n_iter=20, n_jobs=1,
#                    param_distributions={'learning_rate': [0.1, 0.2],
#                                         'max_depth': [2, 3, 4, 5],
#                                         'n_estimators': [80, 100, 120, 130,
#                                                          140]},
#                    scoring='neg_mean_squared_error', verbose=1)

# %%
xgbr.best_params_
# Out:
# {'n_estimators': 80, 'max_depth': 3, 'learning_rate': 0.1}

# %%
model_xgb = XGBRegressor(n_estimators= 80, max_depth= 3, random_state=42, 
                         n_jobs=-1,learning_rate=0.1, objective='reg:squarederror')

# %%
model1 = evaluate(model_xgb)
# Out:
# train RMSE                 : 1052.284404211307
# validatin RMSE             : 1029.8115980149041
# R2 Score on Validation data: 0.6206841067930488
# R2 Score on training data  : 0.6213508866128774

# %%
import lightgbm as lgb

# %%
params = {
    'objective': 'regression',
    'max_bin': 300,
    'learning_rate': 0.02,
    'num_leaves': 50,
}

# %%
lgb_train = lgb.Dataset(x_train, y_train)
lgb_eval = lgb.Dataset(x_val, y_val,reference=lgb_train)
model_lgb = lgb.train(params, lgb_train,
                      valid_sets=[lgb_train, lgb_eval],
                      verbose_eval=10,
                      num_boost_round=10000,
                      early_stopping_rounds=20)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000124 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 642
# [LightGBM] [Info] Number of data points in the train set: 7670, number of used features: 8
# [LightGBM] [Info] Start training from score 2187.156299
# Training until validation scores don't improve for 20 rounds
# [10]	training's l2: 2.32086e+06	valid_1's l2: 2.21331e+06
# [20]	training's l2: 1.91329e+06	valid_1's l2: 1.82405e+06
# [30]	training's l2: 1.63657e+06	valid_1's l2: 1.56879e+06
# [40]	training's l2: 1.4474e+06	valid_1's l2: 1.40325e+06
# [50]	training's l2: 1.31769e+06	valid_1's l2: 1.29705e+06
# [60]	training's l2: 1.22639e+06	valid_1's l2: 1.22139e+06
# [70]	training's l2: 1.16174e+06	valid_1's l2: 1.17003e+06
# [80]	training's l2: 1.11496e+06	valid_1's l2: 1.13332e+06
# [90]	training's l2: 1.08053e+06	valid_1's l2: 1.11207e+06
# [100]	training's l2: 1.0539e+06	valid_1's l2: 1.09875e+06
# [110]	training's l2: 1.03225e+06	valid_1's l2: 1.08793e+06
# [120]	training's l2: 1.01436e+06	valid_1's l2: 1.08097e+06
# [130]	training's l2: 998988	valid_1's l2: 1.07655e+06
# [140]	training's l2: 984652	valid_1's l2: 1.07376e+06
# [150]	training's l2: 971397	valid_1's l2: 1.07051e+06
# [160]	training's l2: 959934	valid_1's l2: 1.07037e+06
# [170]	training's l2: 948445	valid_1's l2: 1.07147e+06
# Early stopping, best iteration is:
# [152]	training's l2: 969011	valid_1's l2: 1.06983e+06

# %%
def evaluate_lgb(model):
    train_pred = model.predict(x_train)
    train_rmse = mean_squared_error(y_train, train_pred, squared=False)
    val_pred = model.predict(x_val)
    val_rmse = mean_squared_error(y_val, val_pred, squared=False)
    r2_train= r2_score(y_train, train_pred)
    r2_val = r2_score(y_val, val_pred)
    print('train RMSE                 :', train_rmse)
    print('validatin RMSE             :', val_rmse)
    print('R2 Score on Validation data:',r2_val)
    print('R2 Score on training data  :',r2_train)
    return model

# %%
model2 = evaluate_lgb(model_lgb)
# Out:
# train RMSE                 : 984.3835510560034
# validatin RMSE             : 1034.3235629309165
# R2 Score on Validation data: 0.6173529940767515
# R2 Score on training data  : 0.6686405407831191

# %%
def ensembled_of_models(model1, model2):
    model1.fit(x_train, y_train)
    train_pred1 = model1.predict(x_train)
    val_pred1 = model1.predict(x_val)
    
    train_pred2 = model2.predict(x_train)
    val_pred2 = model2.predict(x_val)
    
    train_pred = (train_pred1+train_pred2)/2
    val_pred = (val_pred1 + val_pred1)/2
    
    r2_train= r2_score(y_train, train_pred)
    r2_val = r2_score(y_val, val_pred)
    
    train_rmse = mean_squared_error(y_train, train_pred, squared=False)
    val_rmse = mean_squared_error(y_val, val_pred, squared=False)
    
    print('R2 Score on Validation data:',r2_val)
    print('R2 Score on training data  :',r2_train)
    print('train RMSE                 :', train_rmse)
    print('validatin RMSE             :', val_rmse)

# %%
ensembled_of_models(model1, model2)
# Out:
# R2 Score on Validation data: 0.6206841067930488
# R2 Score on training data  : 0.6482155359360913
# train RMSE                 : 1014.2686206715866
# validatin RMSE             : 1029.8115980149041
